# %% [markdown]
# # 1. Wordnet 사용방법
#
# Natural Language Toolkit (NLTK) 라이브러리를 사용한 예제

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# WordNet 라이브러리를 사용하기 위해 NLTK에서 wordnet 모듈을 불러옴
from nltk.corpus import wordnet

# 'dog'라는 단어와 관련된 모든 synset(동의어 집합)을 가져옴
# Synset: WordNet에서 단어의 여러 의미(sense)를 묶어 놓은 집합
synsets = wordnet.synsets('dog')

# synsets 리스트 중 첫 번째 synset의 정의(definition)를 확인
# synsets[0] → 'dog'의 가장 대표적인 의미(보통 빈도가 높은 의미)
print("dog의 정의:", synsets[0].definition())
# Out:
# dog의 정의: a member of the genus Canis (probably descended from the common wolf) that has been domesticated by man since prehistoric times; occurs in many breeds

# %%
# WordNet에서 'happy'라는 단어의 모든 synset(동의어 집합)을 가져옴
happy_synsets = wordnet.synsets('happy')

# 동의어(lemma) 추출
# 각 synset 안에는 여러 lemma(단어 형태)가 포함되어 있음
# synset.lemmas() → 해당 의미를 나타내는 단어 리스트
# lemma.name() → lemma의 실제 단어 문자열을 가져옴
print("happy의 동의어:", [lemma.name() for synset in happy_synsets for lemma in synset.lemmas()])

# 반의어 추출
# lemma.antonyms() → 해당 lemma의 반의어 리스트를 반환 (비어 있을 수도 있음)
# if lemma.antonyms() → 반의어가 있는 경우만 선택
# lemma.antonyms()[0].name() → 첫 번째 반의어 단어 문자열을 가져옴
print("happy의 반의어:", [lemma.antonyms()[0].name() for synset in happy_synsets for lemma in synset.lemmas() if lemma.antonyms()])
# Out:
# happy의 동의어: ['happy', 'felicitous', 'happy', 'glad', 'happy', 'happy', 'well-chosen']
# happy의 반의어: ['unhappy']

# %%
# 'dog' 단어의 첫 번째 synset 선택 (보통 가장 일반적인 의미: 애완견/가축화된 개)
dog_synset = synsets[0]

# 상위어(hypernym) 확인
# hypernyms() → 해당 synset이 속하는 더 일반적인 개념(상위 개념)들을 반환
hypernyms = dog_synset.hypernyms()
# 각 상위어 synset의 이름(name)을 출력
print("dog의 상위어:", [hypernym.name() for hypernym in hypernyms])

# 하위어(hyponym) 확인
# hyponyms() → 해당 synset에 속하는 더 구체적인 개념(하위 개념)들을 반환
hyponyms = dog_synset.hyponyms()
# 각 하위어 synset의 이름(name)을 출력
print("dog의 하위어:", [hyponym.name() for hyponym in hyponyms])
# Out:
# dog의 상위어: ['domestic_animal.n.01', 'canine.n.02']
# dog의 하위어: ['cur.n.01', 'pooch.n.01', 'lapdog.n.01', 'spitz.n.01', 'basenji.n.01', 'corgi.n.01', 'great_pyrenees.n.01', 'griffon.n.02', 'toy_dog.n.01', 'mexican_hairless.n.01', 'puppy.n.01', 'working_dog.n.01', 'hunting_dog.n.01', 'poodle.n.01', 'leonberg.n.01', 'newfoundland.n.01', 'pug.n.01', 'dalmatian.n.02']

# %% [markdown]
# ***wordnet 관련 패키지 nltk import***

# %%
import nltk
# NLTK: 자연어처리를 위한 대표적인 파이썬 라이브러리 (Natural Language Toolkit)

# 필요한 데이터셋 다운로드 (처음 한 번만 실행하면 됨)
nltk.download('wordnet')       # WordNet: 단어 의미, 동의어/반의어, 계층 구조 등 제공
nltk.download('punkt')         # punkt: 문장/단어를 토큰화(쪼개기)할 때 필요
nltk.download('punkt_tab')     # punkt_tab: punkt 토큰화의 보조 리소스
nltk.download('stopwords')     # stopwords: 분석에 큰 의미가 없는 불용어 목록 (예: the, is, a)

# WordNet 코퍼스 불러오기
from nltk.corpus import wordnet
# → 단어의 동의어, 반의어, 상위어, 하위어 등을 쉽게 조회할 수 있음

# 단어 토큰화 함수 불러오기
from nltk import word_tokenize
# → 문장을 단어 단위로 쪼개어 리스트로 변환

# 불용어(stopwords) 불러오기
from nltk.corpus import stopwords
# → 'the', 'is', 'at' 같은 의미 없는 단어들을 미리 정의한 리스트 제공

# 영어 불용어 집합 불러오기
stopwords = set(stopwords.words('english'))
# → stopwords 변수에 영어 불용어 모음을 저장
#    예: {'i', 'my', 'they', 'the', 'is', ...}

import sys
# 파이썬 시스템 관련 기능 제공 모듈
# 예) sys.exit() → 프로그램 강제 종료
#     sys.path → 모듈 검색 경로 확인/추가
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # 2. Lesk 알고리즘
# ### Lesk 알고리즘을 사용하여 주어진 문장에서 'word'의 가장 적절한 의미(sense)를 찾는 함수
# ***단어와  문장에 나타난 단어에 대해  Best Sense 추출***

# %%
# Lesk 알고리즘을 사용하여 주어진 문장에서 'word'의 가장 적절한 의미(sense)를 찾는 함수
def disambiguate(word, sentence, stopwords):

    word_senses = wordnet.synsets(word)
    # WordNet에서 해당 단어(word)의 모든 의미(synset)를 가져옴
    # 예: "bank" → [은행(financial institution), 강둑(river edge) ...]

    best_sense = word_senses[0]
    # 초기값: 첫 번째 의미를 기본값으로 설정
    # WordNet은 보통 가장 자주 쓰이는 의미를 첫 번째로 배치

    max_overlap = 0
    # 문맥과 가장 많이 겹치는 단어 수를 기록하기 위한 변수

    context = set(word_tokenize(sentence))
    # 입력 문장을 단어 단위로 토큰화 → 집합(set) 형태로 변환
    # 예: "I went to the bank" → {"I", "went", "to", "the", "bank"}
    # 이 집합이 문맥(context) 단어들의 모음이 됨

    for sense in word_senses:
        # 후보 의미(sense) 하나씩 확인 (예: 은행 / 강둑)

        signature = tokenized_gloss(sense)
        # 해당 의미의 정의(gloss) + 예문(example)을 토큰화하여 단어 집합(signature) 생성
        # 예: bank(financial institution)의 정의 → {"financial", "institution", "money", ...}

        overlap = compute_overlap(signature, context, stopwords)
        # signature 단어들과 문맥(context) 단어들 사이의 겹치는 단어 개수 계산
        # stopwords(불용어)는 제거하여 의미 있는 단어만 비교
        # 예: context {"river", "bank"} ∩ gloss {"river", "edge"} → overlap = 1

        if overlap > max_overlap:
            # 지금까지 찾은 것보다 겹치는 단어 수가 더 많으면 갱신
            max_overlap = overlap
            best_sense = sense
            # 가장 적절한 의미 후보(best_sense) 업데이트

    return best_sense
    # 문맥과 가장 많이 겹친 의미(sense)를 최종 반환
    # 예: "I went to the bank to deposit money" → "은행(financial institution)"

# %% [markdown]
# ***sense의 definition에 대한 모든 token 추출***

# %%
# 특정 synset(단어의 한 의미)에 대해 정의(definition)와 예문(examples)을 토큰화하여 단어 집합 생성
def tokenized_gloss(sense):
    tokens = set(word_tokenize(sense.definition()))
    # synset의 정의(definition)를 단어 단위로 토큰화하여 집합(set)으로 변환
    # 예: 'dog' → "a domesticated carnivorous mammal" → {"a", "domesticated", "carnivorous", "mammal"}

    for example in sense.examples():
        # 해당 synset이 가진 모든 예문(example)에 대해 반복
        tokens = tokens.union(set(word_tokenize(example)))
        # 예문을 토큰화한 집합과 기존 tokens를 합집합(union)으로 결합

    return tokens
    # 정의와 예문에 등장한 모든 단어들의 집합 반환

# %% [markdown]
# ***겹치는 단어 비교***

# %%
# signature: synset의 정의(definition)와 예문(example)에서 추출한 단어 집합
# context: 문맥 문장에서 추출한 단어 집합
# stopwords: 불용어 집합 (의미 없는 단어 제거용)

def compute_overlap(signature, context, stopwords):
    gloss = signature.difference(stopwords)
    # signature 집합에서 stopwords를 제거하여 의미 있는 단어만 남김
    # 예: {"the", "dog", "animal"} - {"the"} → {"dog", "animal"}

    return len(gloss.intersection(context))
    # 문맥(context)과 signature(gloss) 간의 교집합 크기(겹치는 단어 수)를 반환
    # 즉, 문맥 속 단어와 synset 정의/예문 속 단어가 얼마나 겹치는지 수치화

# %% [markdown]
# ***Lesk 알고리즘을 실제로 동작시키는 예제***

# %%
# 입력 문장 정의
sentence = "They eat a meal"

# 문장을 단어 단위로 토큰화하여 문맥(context) 집합 생성
# 예: {"They", "eat", "a", "meal"}
context = set(word_tokenize(sentence))

# 의미 중의성 해소 대상 단어
word = 'eat'

print("🔎 Target Word:", word)
print("📌 Input Sentence:", sentence)
# Out:
# 🔎 Target Word: eat
# 📌 Input Sentence: They eat a meal

# %%
# 'eat' 단어의 모든 synset(후보 의미) 출력
# syn.name() → synset 이름 (예: eat.v.01)
# syn.definition() → 의미 정의
print("➡ Candidate Senses for 'eat':")
for i, syn in enumerate(wordnet.synsets(word)):
    print(f"{i}. {syn.name()}  |  Definition: {syn.definition()}")
# Out:
# ➡ Candidate Senses for 'eat':
# 0. eat.v.01  |  Definition: take in solid food
# 1. eat.v.02  |  Definition: eat a meal; take a meal
# 2. feed.v.06  |  Definition: take in food; used of animals only
# 3. eat.v.04  |  Definition: worry or cause anxiety in a persistent way
# 4. consume.v.05  |  Definition: use up (resources or materials)
# 5. corrode.v.01  |  Definition: cause to deteriorate due to the action of water, air, or an acid

# %%
# 예시로 'eat'의 두 번째 synset을 선택하여 확인
syn = wordnet.synsets('eat')[1]

print("🔹 Checking Sense:", syn.name())
print(" - Definition :", syn.definition())

# tokenized_gloss(syn) → synset의 정의와 예문을 토큰화하여 단어 집합 생성
print(" - Gloss Tokens:", tokenized_gloss(syn))

# 현재 입력 문장의 문맥 단어 집합 출력
print(" - Context Tokens:", context)
# Out:
# 🔹 Checking Sense: eat.v.02
#  - Definition : eat a meal; take a meal
#  - Gloss Tokens: {'eat', 'many', 'there', 'a', 'so', 'invitation', 'accept', '10', 'yet', 'until', 'gladly', ',', 'were', 'calls', 'take', 'We', 'I', 'not', 'because', 'did', ';', 'your', 'P.M.', "n't", 'phone', 'meal'}
#  - Context Tokens: {'eat', 'They', 'meal', 'a'}

# %%
# signature와 context 간의 겹치는 단어 수 계산
print(" - Overlap with Context:", compute_overlap(tokenized_gloss(syn), context, stopwords))
print("="*50)

# Lesk algorithem 실행: 문맥과 가장 잘 맞는 의미(best sense) 선택
best_sense = disambiguate(word, sentence, stopwords)

# 최종 선택된 synset과 정의 출력
print("✅ Best Sense Selected:", best_sense.name())
print(" - Definition:", best_sense.definition())
# Out:
#  - Overlap with Context: 2
# ...
# ✅ Best Sense Selected: eat.v.02
#  - Definition: eat a meal; take a meal

# %% [markdown]
# # 3. 그래프 기반(NetworkX + WordNet) WSD 구현 예제

# %%
# =============================
# Graph-based WSD (Knowledge-based) with WordNet + PageRank
# =============================

# (1) 필요한 라이브러리 임포트
import nltk
from nltk.corpus import wordnet as wn
from nltk import word_tokenize
from nltk.corpus import stopwords as nltk_stopwords
import networkx as nx

# ※ 처음 한 번만 실행(리소스 다운로드)
# nltk.download('wordnet')
# nltk.download('omw-1.4')   # WordNet 유사도 개선(권장)
# nltk.download('punkt')
# nltk.download('stopwords')

# %%
# ==== (도움 함수) synset을 보기 좋게 문자열로 =======================================
def synset_str(s):
    """예: Synset('bank.n.01') -> 'bank.n.01 :: financial institution ...'"""
    return f"{s.name()} :: {s.definition()}"

# ==== (1) 유틸 함수들 ================================================================
def get_synsets(word, max_n=3):
    """
    주어진 단어의 synset 후보 리스트(WordNet 의미들)를 상위 max_n개만 반환.
    - 그래프가 너무 커지는 것을 방지하기 위해 개수를 제한합니다.
    """
    return wn.synsets(word)[:max_n]

def wup_sim(s1, s2):
    """
    Wu–Palmer 유사도 계산(동일 품사일 때 특히 적합).
    - 유사도가 None이면 0.0으로 처리하여 계산을 안정화합니다.
    """
    sim = s1.wup_similarity(s2)
    return float(sim) if sim is not None else 0.0

def build_semantic_graph(target_word, context_words, max_synsets_each=3, sim_threshold=0.1):
    """
    의미 그래프 생성:
      - 노드: (word, synset) 튜플  (예: ('bank', Synset('bank.n.01')))
      - 엣지: synset 간 유사도(Wu–Palmer)가 임계값 이상일 때 추가, 가중치=유사도
    """
    G = nx.Graph()

    # 1) 대상 단어 + 문맥 단어들의 synset 후보 수집
    cand_by_word = {}
    cand_by_word[target_word] = get_synsets(target_word, max_synsets_each)
    for w in context_words:
        cand_by_word[w] = get_synsets(w, max_synsets_each)

    # 2) 노드 추가
    for w, syns in cand_by_word.items():
        for s in syns:
            G.add_node((w, s))

    # 3) 엣지 추가: 모든 후보 synset 쌍에 대해 유사도 계산
    #    (잡음을 줄이기 위해 같은 품사(pos)끼리만 비교)
    nodes = list(G.nodes())
    for i in range(len(nodes)):
        for j in range(i + 1, len(nodes)):
            (w1, s1), (w2, s2) = nodes[i], nodes[j]
            if s1.pos() == s2.pos():
                sim = wup_sim(s1, s2)
                if sim >= sim_threshold:
                    G.add_edge((w1, s1), (w2, s2), weight=sim)

    return G, cand_by_word

# ==== (2) 그래프 기반 WSD 메인 =======================================================
def graph_based_wsd(target_word, sentence):
    """
    그래프 기반 WSD (개념 흐름):
      1) 문장을 토큰화 → 불용어 제거 → 문맥 단어 추출
      2) 대상/문맥 단어의 synset 후보로 그래프 구성 (엣지=유사도)
      3) Personalized PageRank 실행 (문맥 노드에 가중치 부여)
      4) 대상 단어의 후보 synset 중 PageRank 점수 최대를 정답으로 선택
    return: (best_synset or None, pagerank_scores(dict), graph)
    """
    # 1) 문맥 준비: 소문자 변환 + 알파벳 토큰만 남기고 + 불용어 제거
    stop_words = set(nltk_stopwords.words('english'))
    tokens = [t.lower() for t in word_tokenize(sentence)]
    # 대상 단어는 남겨두고, 나머지 중 불용어/비알파벳 제거
    context_words = [t for t in tokens if t.isalpha() and t not in stop_words and t != target_word.lower()]

    # 2) 의미 그래프 구성
    G, cand_by_word = build_semantic_graph(
        target_word=target_word.lower(),
        context_words=context_words,
        max_synsets_each=3,   # 각 단어당 최대 3개 synset만 사용(시연/학습용)
        sim_threshold=0.1     # 유사도 임계값(낮을수록 엣지가 많아짐)
    )

    # 그래프가 비면(노드 없음) 바로 종료
    if len(G) == 0:
        return None, {}, G

    # 3) Personalized PageRank용 personalization 벡터 준비
    #    아이디어: "문맥 단어 후보 노드"에 가중치(시작 확률)를 몰아줌
    personalization = {node: 0.0 for node in G.nodes()}
    for w in context_words:
        for s in cand_by_word.get(w, []):
            node = (w, s)
            if node in personalization:
                personalization[node] = 1.0

    # 문맥 노드가 전혀 없으면 균등 분포 사용
    if not any(personalization.values()):
        personalization = None  # networkx가 내부적으로 균등 분포 사용

    # 4) PageRank 실행 (가중치 사용)
    pr = nx.pagerank(G, alpha=0.85, personalization=personalization, weight='weight')

    # 5) 대상 단어의 후보 synset 중 PageRank 점수 최댓값 선택
    target_candidates = [(w, s) for (w, s) in G.nodes() if w == target_word.lower()]
    if not target_candidates:
        return None, pr, G

    best_node = max(target_candidates, key=lambda n: pr.get(n, 0.0))
    best_synset = best_node[1]
    return best_synset, pr, G

# %%
# =============================
# (3) Demo: Sentence and Target Word
# =============================
sentence = "I sat on the bank of the river"
target = "bank"

# 그래프 기반 WSD 실행: (가장 그럴듯한 synset, PageRank 점수 dict, 그래프)
best, pr_scores, graph = graph_based_wsd(target, sentence)

# -----------------------------
# 1) 입력/대상 정보 출력
# -----------------------------
print("📌 Input Sentence:", sentence)
print("🔎 Target Word   :", target)
print("=" * 60)

# -----------------------------
# 2) 후보 의미(상위 5개) 미리 살펴보기
#    - WordNet에서 'bank'가 가질 수 있는 대표 의미들을 확인
# -----------------------------
cands = wn.synsets(target)[:5]   # 최대 5개까지만 출력 (너무 길어지는 것 방지)
print("➡ Candidate Senses for 'bank':")
if not cands:
    print("  (No synsets found in WordNet.)")
else:
    for i, s in enumerate(cands, start=1):
        # s.name(): bank.n.01 같은 내부 식별자
        # s.pos(): 품사 (n=명사, v=동사, a=형용사, r=부사)
        # s.definition(): 해당 의미의 정의(영어)
        print(f"{i}. {s.name():<20} | POS={s.pos()} | Definition: {s.definition()}")
print("=" * 60)

# -----------------------------
# 3) 그래프 기반 선택 결과 출력
#    - Personalized PageRank 결과로 선택된 최종 의미
# -----------------------------
if best is not None:
    print("✅ Best Sense Selected (Graph-based WSD):")
    print(f" - Synset name : {best.name()}")        # 예: bank.n.01
    print(f" - POS         : {best.pos()}")         # 예: n
    print(f" - Definition  : {best.definition()}")  # 예: 'sloping land ...' 등
    print("=" * 60)
else:
    print("❌ No best sense found (graph was empty or no target candidates).")
    # 그래프가 비었을 수 있는 상황:
    # - 문맥 단어들이 WordNet에 잘 없는 경우
    # - synset 수 제한/유사도 임계값이 너무 높아서 엣지가 거의 없는 경우
    # - 언어가 영어가 아닌 경우 (현재 stopwords/토큰화는 영어 기준)
    print("=" * 60)

# -----------------------------
# 4) (선택) PageRank 상위 후보 3개 확인
#    - 어떤 (단어, synset) 노드들이 점수가 높았는지 확인
# -----------------------------
print("📊 Top-ranked Synsets (PageRank scores):")
if not pr_scores:
    print("  (No PageRank scores computed.)")
else:
    # pr_scores: {(word, synset): score}
    sorted_pr = sorted(pr_scores.items(), key=lambda x: x[1], reverse=True)
    topk = min(3, len(sorted_pr))
    for (w, s), score in sorted_pr[:topk]:
        print(f" - {w}: {s.name()}  (score={score:.4f})")
# Out:
# 📌 Input Sentence: I sat on the bank of the river
# 🔎 Target Word   : bank
# ...
# ➡ Candidate Senses for 'bank':
# 1. bank.n.01            | POS=n | Definition: sloping land (especially the slope beside a body of water)
# 2. depository_financial_institution.n.01 | POS=n | Definition: a financial institution that accepts deposits and channels the money into lending activities
# 3. bank.n.03            | POS=n | Definition: a long ridge or pile
# 4. bank.n.04            | POS=n | Definition: an arrangement of similar objects in a row or in tiers
# 5. bank.n.05            | POS=n | Definition: a supply or stock held in reserve for future use (especially in emergencies)
# ...
# ✅ Best Sense Selected (Graph-based WSD):
#  - Synset name : bank.n.01
#  - POS         : n
#  - Definition  : sloping land (especially the slope beside a body of water)
# ...
# 📊 Top-ranked Synsets (PageRank scores):
#  - sat: sit.v.01  (score=0.2500)
#  - sat: sit.v.02  (score=0.2500)
#  - river: river.n.01  (score=0.1172)
